# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("/content/movies_metadata.csv", low_memory=False, on_bad_lines='warn')

# %%
df.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42640 entries, 0 to 42639
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  42640 non-null  object
#  1   belongs_to_collection  4264 non-null   object
#  2   budget                 42640 non-null  object
#  3   genres                 42640 non-null  object
#  4   homepage               7331 non-null   object
#  5   id                     42640 non-null  object
#  6   imdb_id                42624 non-null  object
#  7   original_language      42633 non-null  object
#  8   original_title         42640 non-null  object
#  9   overview               41812 non-null  object
#  10  popularity             42635 non-null  object
#  11  poster_path            42307 non-null  object
#  12  production_companies   42637 non-null  object
#  13  production_countries   42637 non-null  object
# ...

# %%
df.columns
# Out:
# Index(['adult', 'belongs_to_collection', 'budget', 'genres', 'homepage', 'id',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'video',
#        'vote_average', 'vote_count'],
#       dtype='object')

# %%
df.shape
# Out:
# (42640, 24)

# %%
df.isnull().sum()
# Out:
# adult                        0
# belongs_to_collection    38376
# budget                       0
# genres                       0
# homepage                 35309
# id                           0
# imdb_id                     16
# original_language            7
# original_title               0
# overview                   828
# popularity                   5
# poster_path                333
# production_companies         3
# production_countries         3
# release_date                70
# revenue                      6
# runtime                    217
# spoken_languages             6
# status                      72
# tagline                  22960
# title                        0
# video                        7
# vote_average                 7
# vote_count                   7
# dtype: int64

# %%
df = df.drop_duplicates().reset_index(drop = True)

# %%
df = df[['title', 'overview', 'genres','tagline','vote_average','popularity']]

# %%
df
# Out:
#                                    title  \
# 0                              Toy Story
# 1                                Jumanji
# 2                       Grumpier Old Men
# 3                      Waiting to Exhale
# 4            Father of the Bride Part II
# ...                                  ...
# 42619  Mo Mandel: Negative Reinforcement
# 42620  Kathleen Madigan: Bothering Jesus
# 42621                     Dan Levy: Lion
# 42622     Aries Spears: Comedy Blueprint
# 42623                                nan
#
#                                                 overview  \
# 0      Led by Woody, Andy's toys live happily in his ...
# 1      When siblings Judy and Peter discover an encha...
# 2      A family wedding reignites the ancient feud be...
# 3      Cheated on, mistreated and stepped on, the wom...
# 4      Just when George Banks has recovered from his ...
# ...                                                  ...
# 42619  Mo Mandel takes the stage in his first hour-lo...
# ...

# %%
df.isnull().sum()
# Out:
# title               0
# overview          828
# genres              0
# tagline         22949
# vote_average        7
# popularity          5
# dtype: int64

# %%
df = df.dropna(subset = ["title"])

# %%
df["popularity"] = pd.to_numeric(
    df["popularity"],
    errors="coerce"
)

df["vote_average"] = pd.to_numeric(
    df["vote_average"],
    errors="coerce"
)

df = df[
    (df["vote_average"] >= 6)
    & (df["popularity"] >= 10)
]

df = df.reset_index(drop=True)

print(df.shape)

# %%
df["overview"] = df["overview"].fillna("")

# %%
import ast
df["genres"] = df["genres"].apply(lambda x: " ".join([i["name"] for i in ast.literal_eval(x)]))

# %%
df.head()
# Out:
#                          title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                             overview  \
# 0  Led by Woody, Andy's toys live happily in his ...
# 1  When siblings Judy and Peter discover an encha...
# 2  A family wedding reignites the ancient feud be...
# 3  Cheated on, mistreated and stepped on, the wom...
# 4  Just when George Banks has recovered from his ...
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                              tagline  vote_average popularity
# ...

# %%
df["tagline"] = df["tagline"].fillna("")

# %%
import re

df["title"] = df["title"].astype(str)

df["title"] = df["title"].apply(
    lambda x: re.sub(r'^[^A-Za-z0-9]+', '', x)
)

# %%
special_titles = df[
    df["title"].str.match(r'^[^A-Za-z0-9]', na=False)
]

print(special_titles["title"].head(20))
print("Count:", len(special_titles))
# Out:
# Series([], Name: title, dtype: object)
# Count: 0

# %%
title = df[df["title"].str.contains("Women Art Revolution", case=False, na=False)]["title"].iloc[0]

print("Title:", repr(title))
print("First character:", repr(title[0]))
print("Is alphanumeric?", title[0].isalnum())
# Out:
# Title: 'Women Art Revolution'
# First character: 'W'
# Is alphanumeric? True

# %%
df.head()
# Out:
#                          title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                             overview  \
# 0  Led by Woody, Andy's toys live happily in his ...
# 1  When siblings Judy and Peter discover an encha...
# 2  A family wedding reignites the ancient feud be...
# 3  Cheated on, mistreated and stepped on, the wom...
# 4  Just when George Banks has recovered from his ...
#
#                      genres  \
# 0   Animation Comedy Family
# 1  Adventure Fantasy Family
# 2            Romance Comedy
# 3      Comedy Drama Romance
# 4                    Comedy
#
#                                              tagline  vote_average popularity
# 0                                                              7.7  21.946943
# 1          Roll the dice and unleash the excitement!           6.9  17.015539
# ...

# %%
df["tags"] = df["overview"] + " " + df["genres"] + " " + df["tagline"]

# %%
df.head()
# Out:
#                          title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                             overview  \
# 0  Led by Woody, Andy's toys live happily in his ...
# 1  When siblings Judy and Peter discover an encha...
# 2  A family wedding reignites the ancient feud be...
# 3  Cheated on, mistreated and stepped on, the wom...
# 4  Just when George Banks has recovered from his ...
#
#                      genres  \
# 0   Animation Comedy Family
# 1  Adventure Fantasy Family
# 2            Romance Comedy
# 3      Comedy Drama Romance
# 4                    Comedy
#
#                                              tagline  vote_average popularity  \
# 0                                                              7.7  21.946943
# 1          Roll the dice and unleash the excitement!           6.9  17.015539
# ...

# %%
df["tags"][1]
# Out:
# "When siblings Judy and Peter discover an enchanted board game that opens the door to a magical world, they unwittingly invite Alan -- an adult who's been trapped inside the game for 26 years -- into their living room. Alan's only hope for freedom is to finish the game, which proves risky as all three find themselves running from giant rhinoceroses, evil monkeys and other terrifying creatures. Adventure Fantasy Family Roll the dice and unleash the excitement!"

# %%
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import re

# %%
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()

# %%
def preprocess_text(text):
  text = str(text.lower())
  text = re.sub(r'[^a-zA-Z\s]' , "" , text)
  words = text.split()
  words = [word for word in words if word not in stop_words]
  words = [lemmatizer.lemmatize(word) for word in words]
  return " ".join(words)

# %%
df["tags"] = df["tags"].apply(preprocess_text)

# %%
df["tags"][1]
# Out:
# 'sibling judy peter discover enchanted board game open door magical world unwittingly invite alan adult who trapped inside game year living room alans hope freedom finish game prof risky three find running giant rhinoceros evil monkey terrifying creature adventure fantasy family roll dice unleash excitement'

# %%
df = df.reset_index(drop = True)

# %%
indices = pd.Series(df.index , index=df['title'])
indices
# Out:
# title
# Toy Story                                0
# Jumanji                                  1
# Grumpier Old Men                         2
# Waiting to Exhale                        3
# Father of the Bride Part II              4
#                                      ...
# Mo Mandel: Negative Reinforcement    42619
# Kathleen Madigan: Bothering Jesus    42620
# Dan Levy: Lion                       42621
# Aries Spears: Comedy Blueprint       42622
# nan                                  42623
# Length: 42624, dtype: int64

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
tfidf = TfidfVectorizer(max_features=5000, ngram_range=(1,2) , stop_words='english')

# %%
tfidf_matrix = tfidf.fit_transform(df["tags"])

# %%
tfidf_matrix
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 1056386 stored elements and shape (42624, 5000)>

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
def recommend(title , n = 10):
  if title not in indices :
    return ["Movie not Found"]
  idx = indices[title]
  sim_score = cosine_similarity(tfidf_matrix[idx] , tfidf_matrix).flatten()
  similar_idx = sim_score.argsort()[::-1][1:n+1]
  return df["title"].iloc[similar_idx]

# %%
recommend("Toy Story")
# Out:
# 28974                    Superstar Goofy
# 2996                         Toy Story 2
# 21921               Toy Story of Terror!
# 25788                    Partysaurus Rex
# 24512                  Hawaiian Vacation
# 31497                          Bar Sport
# 37287    Father of Four: Never Gives Up!
# 14339            Darkness/Light/Darkness
# 24310             Moomins on the Riviera
# 21983                         Free Birds
# Name: title, dtype: object

# %%
recommend("i Saw the devil")
# Out:
# ['Movie not Found']

# %%
import pickle
pickle.dump(tfidf_matrix, open('tfidf_matrix.pkl', 'wb'))
pickle.dump(indices, open('indices.pkl','wb'))
df.to_pickle('df.pkl')
pickle.dump(tfidf , open('tfidf.pkl','wb'))
